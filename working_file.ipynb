# %% [markdown]
# # Data Cleaner for Delighted Scores
# This app will clean up raw data that's exported from Delighted, in preparation for importing it into Accelo.  The specific steps which it will complete are:
# - Remove all columns except for:
# -- Name
# -- Email
# -- Score
# -- Comment
# -- Response Timestamp
# -- Access Level
# -- Company Name
# -- Company ID
# -- Delighted Country
# -- Domain
# -- Industry
# -- Manager
# -- MRR
# - Change "Score" column's "0" rows to "Zero"
# - Copy "Score" column's content into new column, and rename it to "Title"
# - Add empty company_id values
# - Format the "Response Timestamp" column as a date
# - Split "Name" column into multiple columns by space

# %%
# Import library dependencies
import pandas as pd
import numpy as np
import requests
import pprint as pp
import math
import re
import base64

# %%
# API Variables
deployment = 'markjellison'
token = 'e0lsIgICJ2rDoxzfFYGEJlgXiA~bfR9y'

# %%
# Query Defaults
email = 'customer.owner.affinitylive@gmail.com'
companyId= '2195'

# %%
# API Endpoint Setup
urlAffiliations = f'https://{deployment}.api.accelo.com/api/v0/affiliations?_fields=id,email,company&_search={email}&_limit=1'
urlCompanies = f'https://{deployment}.api.accelo.com/api/v0/companies?_filters=id({companyId})&_fields=name&_limit=1'

# %%
# API Header Setup
headers = {'Content-Type': 'application/json',
          'Authorization': f'Bearer {token}'}

# %%
try:
    # Open the source CSV
    source = pd.read_csv('CSV Files/delighted-data_24-February-2020.csv')
    source.head()
except:
    print("Bad filename")

# %%
# Open the source CSV
source = pd.read_csv('CSV Files/delighted-data_24-February-2020.csv')
source.head()
# Out:
#    Response ID                 Name                           Email  Score  \
# 0    115439005      Kenneth Sejberg           kse@simplesolution.dk      0
# 1    115435153    Valentina Schichl  valentina.schichl@kaiser-x.com      2
# 2    115431073         Velton Davis     velton@prospergroupcorp.com      3
# 3    115393412  Francesca McMaster          fmcmaster@extent.com.au      0
# 4    115393239      Plamen | Verve?       plamen@verve-design.co.uk      0
#
#    Asset Title                                 Comment Response Timestamp  \
# 0            0                                     NaN     2/24/2020 2:56
# 1            0                                     NaN     2/24/2020 1:19
# 2            0  Very slow, convoluted, several errors.    2/23/2020 23:36
# 3            0                                     NaN    2/23/2020 14:14
# 4            0                                     NaN    2/23/2020 14:12
#
#    Notes  Tags  access_level  ...  financial_visibility  industry_template  \
# 0    NaN   NaN  professional  ...                   NaN      it-consulting
# 1    NaN   NaN  professional  ...                   NaN      it-consulting
# 2    NaN   NaN  professional  ...                   NaN  digital-marketing
# 3    NaN   NaN  professional  ...                   NaN              other
# 4    NaN   NaN  professional  ...                   NaN         web-design
#
#         manager monthly_spend pro_users product projects psa retainers  \
# 0  Marie Barker        2070.0        30     psa  premium NaN   premium
# 1  Marie Barker        4182.0        95   mixed  premium NaN       NaN
# 2  Marie Barker        2530.0        48     psa  premium NaN   premium
# 3   Amy Stewart        2450.0        53   mixed  premium NaN       NaN
# 4    Clay Hagen         759.0        10     psa  premium NaN   premium
#
#    service
# 0  premium
# 1      NaN
# 2  premium
# 3      NaN
# 4  premium
#
# [5 rows x 34 columns]

# %%
# Create a new DF with just the relevant columns
data = source[['Name', 'Email', 'Score', 'Comment', 'Response Timestamp', 'access_level', 'company_id', 'company_name', 'Delighted Country', 'domain', 'industry_template', 'manager', 'monthly_spend']]
data.head()
# Out:
#                   Name                           Email  Score  \
# 0      Kenneth Sejberg           kse@simplesolution.dk      0
# 1    Valentina Schichl  valentina.schichl@kaiser-x.com      2
# 2         Velton Davis     velton@prospergroupcorp.com      3
# 3  Francesca McMaster          fmcmaster@extent.com.au      0
# 4      Plamen | Verve?       plamen@verve-design.co.uk      0
#
#                                   Comment Response Timestamp  access_level  \
# 0                                     NaN     2/24/2020 2:56  professional
# 1                                     NaN     2/24/2020 1:19  professional
# 2  Very slow, convoluted, several errors.    2/23/2020 23:36  professional
# 3                                     NaN    2/23/2020 14:14  professional
# 4                                     NaN    2/23/2020 14:12  professional
#
#    company_id                      company_name Delighted Country  \
# 0    194190.0                   Simple Solution           Denmark
# 1    199938.0                     Kaiser X Labs           Germany
# 2    175217.0                 The Prosper Group     United States
# 3    180972.0                   Extent Heritage         Australia
# 4    152975.0  Verve Graphic Design & Marketing    United Kingdom
#
#                           domain  industry_template       manager  \
# 0      simplesolution.accelo.com      it-consulting  Marie Barker
# 1         kaiserxlabs.accelo.com      it-consulting  Marie Barker
# 2  prosper-group-corp.accelo.com  digital-marketing  Marie Barker
# 3              extent.accelo.com              other   Amy Stewart
# 4               verve.accelo.com         web-design    Clay Hagen
#
#    monthly_spend
# 0         2070.0
# 1         4182.0
# 2         2530.0
# 3         2450.0
# 4          759.0

# %%
# Rename the columns
data = data.rename(columns={"access_level": "Access Level", "company_id": "Company ID", "company_name": "Company Name", "domain": "Domain", "industry_template": "Industry", "manager": "Manager", "monthly_spend": "MRR", "Name": "Original Name"})
data.head()
# Out:
#          Original Name                           Email  Score  \
# 0      Kenneth Sejberg           kse@simplesolution.dk      0
# 1    Valentina Schichl  valentina.schichl@kaiser-x.com      2
# 2         Velton Davis     velton@prospergroupcorp.com      3
# 3  Francesca McMaster          fmcmaster@extent.com.au      0
# 4      Plamen | Verve?       plamen@verve-design.co.uk      0
#
#                                   Comment Response Timestamp  Access Level  \
# 0                                     NaN     2/24/2020 2:56  professional
# 1                                     NaN     2/24/2020 1:19  professional
# 2  Very slow, convoluted, several errors.    2/23/2020 23:36  professional
# 3                                     NaN    2/23/2020 14:14  professional
# 4                                     NaN    2/23/2020 14:12  professional
#
#    Company ID                      Company Name Delighted Country  \
# 0    194190.0                   Simple Solution           Denmark
# 1    199938.0                     Kaiser X Labs           Germany
# 2    175217.0                 The Prosper Group     United States
# 3    180972.0                   Extent Heritage         Australia
# 4    152975.0  Verve Graphic Design & Marketing    United Kingdom
#
#                           Domain           Industry       Manager     MRR
# 0      simplesolution.accelo.com      it-consulting  Marie Barker  2070.0
# 1         kaiserxlabs.accelo.com      it-consulting  Marie Barker  4182.0
# 2  prosper-group-corp.accelo.com  digital-marketing  Marie Barker  2530.0
# 3              extent.accelo.com              other   Amy Stewart  2450.0
# 4               verve.accelo.com         web-design    Clay Hagen   759.0

# %%
data.loc[(data.Score == 0), 'Score']='Zero'
data.head()
# Out:
#          Original Name                           Email Score  \
# 0      Kenneth Sejberg           kse@simplesolution.dk  Zero
# 1    Valentina Schichl  valentina.schichl@kaiser-x.com     2
# 2         Velton Davis     velton@prospergroupcorp.com     3
# 3  Francesca McMaster          fmcmaster@extent.com.au  Zero
# 4      Plamen | Verve?       plamen@verve-design.co.uk  Zero
#
#                                   Comment Response Timestamp  Access Level  \
# 0                                     NaN     2/24/2020 2:56  professional
# 1                                     NaN     2/24/2020 1:19  professional
# 2  Very slow, convoluted, several errors.    2/23/2020 23:36  professional
# 3                                     NaN    2/23/2020 14:14  professional
# 4                                     NaN    2/23/2020 14:12  professional
#
#    Company ID                      Company Name Delighted Country  \
# 0    194190.0                   Simple Solution           Denmark
# 1    199938.0                     Kaiser X Labs           Germany
# 2    175217.0                 The Prosper Group     United States
# 3    180972.0                   Extent Heritage         Australia
# 4    152975.0  Verve Graphic Design & Marketing    United Kingdom
#
#                           Domain           Industry       Manager     MRR
# 0      simplesolution.accelo.com      it-consulting  Marie Barker  2070.0
# 1         kaiserxlabs.accelo.com      it-consulting  Marie Barker  4182.0
# 2  prosper-group-corp.accelo.com  digital-marketing  Marie Barker  2530.0
# 3              extent.accelo.com              other   Amy Stewart  2450.0
# 4               verve.accelo.com         web-design    Clay Hagen   759.0

# %%
# Copy the contents of the Score column as "Title"
data['Title'] = data['Score']
data.head()
# Out:
#          Original Name                           Email Score  \
# 0      Kenneth Sejberg           kse@simplesolution.dk  Zero
# 1    Valentina Schichl  valentina.schichl@kaiser-x.com     2
# 2         Velton Davis     velton@prospergroupcorp.com     3
# 3  Francesca McMaster          fmcmaster@extent.com.au  Zero
# 4      Plamen | Verve?       plamen@verve-design.co.uk  Zero
#
#                                   Comment Response Timestamp  Access Level  \
# 0                                     NaN     2/24/2020 2:56  professional
# 1                                     NaN     2/24/2020 1:19  professional
# 2  Very slow, convoluted, several errors.    2/23/2020 23:36  professional
# 3                                     NaN    2/23/2020 14:14  professional
# 4                                     NaN    2/23/2020 14:12  professional
#
#    Company ID                      Company Name Delighted Country  \
# 0    194190.0                   Simple Solution           Denmark
# 1    199938.0                     Kaiser X Labs           Germany
# 2    175217.0                 The Prosper Group     United States
# 3    180972.0                   Extent Heritage         Australia
# 4    152975.0  Verve Graphic Design & Marketing    United Kingdom
#
#                           Domain           Industry       Manager     MRR  \
# 0      simplesolution.accelo.com      it-consulting  Marie Barker  2070.0
# 1         kaiserxlabs.accelo.com      it-consulting  Marie Barker  4182.0
# 2  prosper-group-corp.accelo.com  digital-marketing  Marie Barker  2530.0
# 3              extent.accelo.com              other   Amy Stewart  2450.0
# 4               verve.accelo.com         web-design    Clay Hagen   759.0
#
#   Title
# 0  Zero
# 1     2
# 2     3
# 3  Zero
# 4  Zero

# %%
for index, row in data.iterrows():
    companyName = row['Company Name']
    splitString = row['Response Timestamp'].split()
    data.loc[(data['Company Name'] == companyName), 'Response Timestamp']=splitString[0]
    
    try:
        if math.isnan(row['Company ID']):
            email = row['Email']
            urlAffiliations = f'https://{deployment}.api.accelo.com/api/v0/affiliations?_fields=id,email,company&_search={email}&_limit=1'
            try:
                response = requests.get(urlAffiliations, headers=headers).json()
                if response['response'] != []:

                    companyId = response['response'][0]['company']
                    data.loc[(data['Company Name'] == companyName), 'Company ID']=companyId                
            except requests.exceptions.RequestException as e:
                print(f'Error: {e}')
    except:
        print("Already processed the dataframe")
print("Processing complete.")
# Out:
# Processing complete.

# %%
# Clean up the respondents' names
names = data['Original Name'].tolist()
updatedNames = []
for name in range(0, len(names)):
    # Remove all the special characters
    document = re.sub(r'\W', ' ', str(names[name]))
    document = re.sub(r'\s+', ' ', document, flags=re.I)
    updatedNames.append(document)
updatedNames
# Out:
# ['Kenneth Sejberg',
#  'Valentina Schichl',
#  'Velton Davis',
#  'Francesca McMaster ',
#  'Plamen Verve ',
#  'Josh Marks',
#  'Chris Bennett',
#  'Sara Moser',
#  'Jessica Owens',
#  'Mike Johnson',
#  'Ben Bryant',
#  'Spencer Jenkins',
#  'Patrick Gatewood',
#  'Todd Huffine',
#  'Charles Stimec',
#  'Jodie Goble',
#  'Esin Ustundag',
#  'Kareem Schwarz',
#  'Tom Dawson',
#  'Ashwin Charles',
#  'James Mumford',
#  'Brandon Greiner',
#  'Gerald Smith',
#  'Dan Sirower',
#  'Tomasz Buklaho',
#  'Matt Douglas',
#  'Gavin Steinberg',
#  'Matthew Scholten',
#  'Samuel Tomkins',
#  'Salvador Fernandez Tejedo',
#  'Monica Popplestone',
#  'Bobi Gavrovski',
#  'Shaun Stanbridge',
#  'Paul Bowen',
#  'Anthony Ranucci',
#  'Shayne Annett',
#  'Tim Dodds',
#  'Ellie Bakker',
#  'Trae Dantzler',
#  'Austin Fisk',
#  'Lucy Arnold',
#  'Marc Andr Dubois',
#  'James Brown',
#  'Hiten Shah',
#  'Bernard Mangelsdorf',
#  'Lee Anne Molony',
#  'Chris Haines',
#  'Sarah Krup',
#  'Pierre Bourassa',
#  'Joe Hoani',
#  'Artwell Nyamugumura',
#  'Christopher Sedlak',
#  'Rex Smith',
#  'Print_1 Mick',
#  'Jason Rainbird',
#  'Dave Wood',
#  'Divyang Sharma',
#  'Anthony Petterson',
#  'Ryan Williams',
#  'Matthew Lee',
#  'Alex Sims',
#  'Nicole Pence',
#  'Benjamin Arnold',
#  'Anthony Innarella',
#  'Myla Marcos',
#  'Maurice Mostert',
#  'David Ligtenberg',
#  'Charles Conley',
#  'Hung Lai',
#  'John Hizer',
#  'David Chamberlain',
#  'Lucio Tilman',
#  'Laura Kelly',
#  'Skye Trudgett',
#  'Ben Auld',
#  'Michelle Brien',
#  'Julian Kearney',
#  'Michael Mazzaferro',
#  'Newlin Jolme',
#  'Paolo Tomasone',
#  'Bj rn Frank',
#  'Mary LeMier',
#  'Michael Felczak',
#  'Michael Doom',
#  'Paul Thewlis',
#  'Melissa Borody',
#  'Mark Brawn',
#  'Mick Maillot',
#  'Micah Thurlow',
#  'Mary Gordon',
#  'Adam Mora',
#  'Birger Celis',
#  'John Noone',
#  'Mark Laursen',
#  'Michelle Di Condio',
#  'Brian Breneman',
#  'Linda Di Girolamo',
#  'Adrian Clark',
#  'Karen Lee',
#  'Steve Douce',
#  'Paul Tormey',
#  'Corey Birkmann',
#  'Michael Cashins CIH',
#  'Nii Otu',
#  'Bronwin Freke',
#  'Mark Bayly',
#  'David Wynn',
#  'Sue Knies',
#  'Jainam Adani',
#  'Flavia Cabanne',
#  'Sven Lancaster',
#  'Martin Briggs',
#  'Nike Sharma',
#  'Brian Houze',
#  'Frans Herle',
#  'Duncan McClure',
#  'Pallavi Sontakke',
#  'Clive Smith',
#  'Alissa Byrne',
#  'Joe Gitchell',
#  'Stuart Watson',
#  'Luisa Cardona',
#  'C J Westrick',
#  'Josh Hay',
#  'Vince Rao',
#  'Andy Neilson',
#  'Conor Sullivan',
#  'Laura Hagi',
#  'Aran Eversman',
#  'M rton Sebesty n',
#  'MacCullagh J Corcoran',
#  'Tim McDaris',
#  'Matthew Lenoir',
#  'CAMILA ALDANA',
#  'Cindy Liu',
#  'Chantelle L tter',
#  'Pranav Shah',
#  'Amanda Engler',
#  'MAKROSAFE Contact',
#  'Peter Johnson',
#  'Lauren Ludik',
#  'Mayur Chauhan',
#  'Jiewen Deng',
#  'Craig Smith',
#  'Khoi Vu',
#  'Jade Hendriks',
#  'Dave Hazan',
#  'James Dziemianzuk',
#  'Daniel LeMier',
#  'Emily Munday',
#  'Jeroen Marchand',
#  'Chris Geiger',
#  'Rosio Barriga',
#  'Joshua Alexander',
#  'Nate Davis',
#  'Tyler Mannix',
#  'Andrew McClatchy',
#  'Mia Mckeown',
#  'Heidi Breton',
#  'Perry Sharma',
#  'Matthew Baptiste',
#  'Richard Watrous',
#  'Dylan Morgan',
#  'Rob Leong',
#  'Melissa Loparco',
#  'Rip Muhlenhaupt',
#  'Geramie Dizon',
#  'Jennifer Stanley',
#  'Benjamin G Saxe',
#  'Luisa Espinosa']

# %%
nameLength = []
name1 = []
name2 = []
name3 = []
name4 = []
name5 = []
for i in updatedNames:
    splitName = i.split()
    name1.append(splitName[0])
    try:
        name2.append(splitName[1])
    except:
        name2.append('')
    try:
        name3.append(splitName[2])
    except:
        name3.append('')
    try:
        name4.append(splitName[3])
    except:
        name4.append('')
    try:
        name5.append(splitName[4])
    except:
        name5.append('')
data['First Name'] = name1
data['Last Name'] = name2
data['Other Name 1'] = name3
data['Other Name 2'] = name4
data['Other Name 3'] = name5

# %%
data.head()
# Out:
#          Original Name                           Email Score  \
# 0      Kenneth Sejberg           kse@simplesolution.dk  Zero
# 1    Valentina Schichl  valentina.schichl@kaiser-x.com     2
# 2         Velton Davis     velton@prospergroupcorp.com     3
# 3  Francesca McMaster          fmcmaster@extent.com.au  Zero
# 4      Plamen | Verve?       plamen@verve-design.co.uk  Zero
#
#                                   Comment Response Timestamp  Access Level  \
# 0                                     NaN          2/24/2020  professional
# 1                                     NaN          2/21/2020  professional
# 2  Very slow, convoluted, several errors.          2/19/2020  professional
# 3                                     NaN          2/23/2020  professional
# 4                                     NaN          2/23/2020  professional
#
#   Company ID                      Company Name Delighted Country  \
# 0     194190                   Simple Solution           Denmark
# 1     199938                     Kaiser X Labs           Germany
# 2     175217                 The Prosper Group     United States
# 3     180972                   Extent Heritage         Australia
# 4     152975  Verve Graphic Design & Marketing    United Kingdom
#
#                           Domain           Industry       Manager     MRR  \
# 0      simplesolution.accelo.com      it-consulting  Marie Barker  2070.0
# 1         kaiserxlabs.accelo.com      it-consulting  Marie Barker  4182.0
# 2  prosper-group-corp.accelo.com  digital-marketing  Marie Barker  2530.0
# 3              extent.accelo.com              other   Amy Stewart  2450.0
# 4               verve.accelo.com         web-design    Clay Hagen   759.0
#
#   Title First Name Last Name Other Name 1 Other Name 2 Other Name 3
# 0  Zero    Kenneth   Sejberg
# 1     2  Valentina   Schichl
# 2     3     Velton     Davis
# 3  Zero  Francesca  McMaster
# 4  Zero     Plamen     Verve

# %%
# Output the result to CSV
data.to_csv('CSV Result/CLEANED.csv', index=False)
